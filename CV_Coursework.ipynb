# %% [markdown]
# # Step 1: GPU Selection
# 1. Find "Edit" tab above, select "Hardware accelerator" and choose "GPU"
# 2. Run bellow command to check what GPU you got

# %%
# !nvidia-smi
# Out:
# Mon Apr  6 19:45:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A4000               On  |   00000000:01:00.0  On |                  Off |
# | 41%   37C    P8             14W /  140W |    6687MiB /  16376MiB |      6%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # Step 2: Code Preparation
#
# We need to maintain our codebase with git history, so a file system (Google Drive) is needed
# 1. Select the left file icon and mount your Google Drive
# 2. Move path to Google Drive
# 3. Git clone code base

# %%
# Install core dependencies directly into the current kernel
# %pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu121
# %pip install numpy scipy pillow h5py yacs tensorboard gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# workspace_dir = '/user/HS400/ms04938/Downloads/CV_Experiments/'
# os.makedirs(workspace_dir, exist_ok=True)
# os.chdir(workspace_dir)

# Clone the repository
# !git clone https://github.com/Surrey-EEEM071-CVDL/Surrey_EEEM071_Coursework.git

# Navigate into the cloned codebase
repo_dir = os.path.join(workspace_dir, 'Surrey_EEEM071_Coursework')
os.chdir(repo_dir)

print(f"Successfully moved into codebase: {os.getcwd()}")
# Out:
# Cloning into 'Surrey_EEEM071_Coursework'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 58 (delta 8), reused 3 (delta 3), pack-reused 31 (from 1)
# Unpacking objects: 100% (58/58), done.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 get_ipython().system('git clone https://github.com/Surrey-EEEM071-CVDL/Surrey_EEEM071_Coursework.git')
#      10 # Navigate into the cloned codebase
# ---> 11 repo_dir = os.path.join(workspace_dir, 'Surrey_EEEM071_Coursework')
#      12 os.chdir(repo_dir)
#      14 print(f"Successfully moved into codebase: {os.getcwd()}")
#
# NameError: name 'workspace_dir' is not defined

# %% [markdown]
# # Step 3: Data Loading
# Use the correct dataset path and make sure all the required folders exists (including loging)

# %%
import os

# Create the master logs directory outside the repo so it doesn't clutter your git status
log_dir = '/scratch/HS400/CV/logs/'
os.makedirs(log_dir, exist_ok=True)
print(f"Logs will be saved to: {log_dir}")

# Verify the dataset exists on the scratch drive
dataset_dir = '/scratch/HS400/CV/VeRi'
if os.path.exists(dataset_dir):
    print(f"Dataset found at: {dataset_dir}")
else:
    print(f"WARNING: Dataset not found at {dataset_dir}. Please check the path!")
# Out:
# Logs will be saved to: /scratch/HS400/CV/logs/
# Dataset found at: /scratch/HS400/CV/VeRi

# %% [markdown]
# # Step 4: Training

# %%
import os
# Move exactly into the src folder where main.py lives
code_dir = "/user/HS400/ms04938/Downloads/CV_Experiments/Surrey_EEEM071_Coursework"
os.chdir(code_dir)

print(f"Successfully moved to: {os.getcwd()}")
# Out:
# Successfully moved to: /user/HS400/ms04938/Downloads/CV_Experiments/Surrey_EEEM071_Coursework

# %%
import sys
import os

# 1. Ensure we are in the repository folder
code_dir = "/user/HS400/ms04938/Downloads/CV_Experiments/Surrey_EEEM071_Coursework"
os.chdir(code_dir)

# 2. Identify the correct Python path
python_path = sys.executable

# 3. Set a SAFE log path within your own user folder
# We use a path relative to where you are now
safe_log_path = "/scratch/HS400/CV/logs/sec1_q1_mobilenet"

print(f"Starting training. Logs will save to: {os.path.abspath(safe_log_path)}")
# Out:
# Starting training. Logs will save to: /scratch/HS400/CV/logs/sec1_q1_mobilenet

# %% [markdown]
# # Section 1: Architecture Experiments
# Goal: Compare different neural network architectures for vehicle Re-ID.

# %% [markdown]
# ## 1.1 MobileNetV3-Small (Baseline)
# Lightweight architecture optimized for mobile deployment.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a mobilenet_v3_small \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec1_mobilenet

# %% [markdown]
# ## 1.2 ResNet-50 (CNN Variant)
# Standard CNN architecture with residual connections.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec1_resnet50

# %% [markdown]
# ## 1.3 VGG16 (Non-ResNet CNN)
# Classic deep CNN without skip connections.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a vgg16 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 32 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec1_vgg16

# %% [markdown]
# ## 1.4 ResNet-18 (Shallow)
# Shallower ResNet to test if fewer layers suffice.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet18 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec1_resnet18

# %% [markdown]
# ## 1.5 ResNet-50 FC512 (Extended Features)
# ResNet-50 with 512-dim embedding layer.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50_fc512 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec1_resnet50_fc512

# %% [markdown]
# ## 1.6 ResNet-34 (Medium Depth)
# Intermediate depth between ResNet-18 and ResNet-50.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet34 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec1_resnet34

# %% [markdown]
# # Section 2: Augmentation Experiments
# Goal: Test data augmentation techniques for robustness.

# %% [markdown]
# ## 2.1 Baseline (Flip + Translation)
# Default augmentation with horizontal flip and random crop.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec2_baseline

# %% [markdown]
# ## 2.2 Baseline + Color Jitter
# Random brightness, contrast, saturation perturbations.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--color-jitter \
--save-dir /scratch/HS400/CV/logs/sec2_jitter

# %% [markdown]
# ## 2.3 Baseline + Random Erasing
# Simulates occlusions by erasing random patches.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--random-erase \
--save-dir /scratch/HS400/CV/logs/sec2_erase

# %% [markdown]
# ## 2.4 Best Combo (Jitter + Erasing)
# Combined augmentation for maximum robustness.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--color-jitter --random-erase \
--save-dir /scratch/HS400/CV/logs/sec2_combo

# %% [markdown]
# ## 2.5 Baseline + Color Augmentation
# RGB channel intensity alterations.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--color-aug \
--save-dir /scratch/HS400/CV/logs/sec2_coloraug

# %% [markdown]
# ## 2.6 Baseline + Label Smoothing
# Soft labels to prevent overconfident predictions.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--label-smooth \
--save-dir /scratch/HS400/CV/logs/sec2_labelsmooth

# %% [markdown]
# # Section 3: Hyperparameter Experiments
# Goal: Optimize learning rate, batch size, optimizer, and other hyperparameters.

# %% [markdown]
# ## 3.1 Learning Rate Sweep
# Test 8 learning rates from 1e-5 to 0.01.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 1e-05 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_lr_1e05

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 3e-05 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_lr_3e05

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0001 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_lr_0_0001

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_lr_0_0003

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.001 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_lr_0_001

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_lr_0_003

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.005 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_lr_0_005

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.01 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_lr_0_01

# %% [markdown]
# ## 3.2 Batch Size Sweep
# Test batch sizes: 16, 32, 64, 128, 256.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 16 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_bs_16

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 32 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_bs_32

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_bs_64

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 128 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_bs_128

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 256 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_bs_256

# %% [markdown]
# ## 3.3 Optimizer Comparison
# Compare AMSGrad, Adam, SGD, RMSprop.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_optim_amsgrad

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim adam --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_optim_adam

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim sgd --lr 0.01 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_optim_sgd

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim rmsprop --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--save-dir /scratch/HS400/CV/logs/sec3_optim_rmsprop

# %% [markdown]
# ## 3.4 Triplet Loss Margin Tuning
# Test margins: 0.1, 0.3, 0.5.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--margin 0.1 \
--save-dir /scratch/HS400/CV/logs/sec3_margin_0_1

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--margin 0.3 \
--save-dir /scratch/HS400/CV/logs/sec3_margin_0_3

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--margin 0.5 \
--save-dir /scratch/HS400/CV/logs/sec3_margin_0_5

# %% [markdown]
# ## 3.5 LR Scheduler Comparison
# Compare multi-step vs single-step decay.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--lr-scheduler multi_step \
--save-dir /scratch/HS400/CV/logs/sec3_sched_multi

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 30 \
--train-batch-size 64 --test-batch-size 100 \
--lr-scheduler single_step \
--save-dir /scratch/HS400/CV/logs/sec3_sched_single

# %% [markdown]
# ## 3.6 Train Sampler: RandomIdentitySampler
# Ensures proper triplet mining with multiple instances per identity.

# %%
# !env STUDENT_ID='6944447' STUDENT_NAME="Mohd Amir Suhel" {python_path} main.py \
-s veri -t veri \
-a resnet50 \
--root /scratch/HS400/CV/ \
--height 224 --width 224 \
--optim amsgrad --lr 0.0003 \
--max-epoch 60 --stepsize 20 40 \
--train-batch-size 64 --test-batch-size 100 \
--train-sampler RandomIdentitySampler --num-instances 4 \
--save-dir /scratch/HS400/CV/logs/sec3_sampler_identity

# %% [markdown]
# ### Rename Log Files

# %%
import os
import re
import shutil
from glob import glob

# Standardize log file names to the coursework pattern: log_sec{Section_num}_q{Question_num}.txt
log_base = "/scratch/HS400/CV/logs/"
out_dir = os.path.join(log_base, "renamed_logs")
os.makedirs(out_dir, exist_ok=True)

section_dirs = {}
for exp_dir in sorted(glob(os.path.join(log_base, "sec*"))):
    exp_name = os.path.basename(exp_dir)
    m = re.match(r"sec(\d+)_", exp_name)
    if not m:
        continue
    sec = m.group(1)
    section_dirs.setdefault(sec, []).append(exp_dir)

renamed = []
for sec in sorted(section_dirs.keys(), key=int):
    for q_idx, exp_dir in enumerate(sorted(section_dirs[sec]), start=1):
        src = os.path.join(exp_dir, "log_train.txt")
        if not os.path.exists(src):
            continue

        new_name = f"log_sec{sec}_q{q_idx}.txt"

        # Keep a copy inside each experiment folder
        dst_local = os.path.join(exp_dir, new_name)
        shutil.copy2(src, dst_local)

        # Keep a central copy for easy submission collection
        exp_suffix = os.path.basename(exp_dir).replace("/", "_")
        dst_central = os.path.join(out_dir, f"{new_name[:-4]}_{exp_suffix}.txt")
        shutil.copy2(src, dst_central)

        renamed.append((src, dst_local, dst_central))

print(f"Renamed/copied {len(renamed)} log files.")
print(f"Central folder: {out_dir}")
for _, local_copy, central_copy in renamed:
    print("-", local_copy)
    print("  ", central_copy)

# %% [markdown]
# # Section 4: Results Collection & Visualization
# Comprehensive analysis of all experiments with tables, plots, and insights.

# %% [markdown]
# ## 4.1 Collect All Results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
from glob import glob

# Set style for all plots
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

log_base = "/scratch/HS400/CV/logs/"

def parse_log(log_dir):
    """Parse training log to extract metrics."""
    log_file = os.path.join(log_dir, "log_train.txt")
    result = {'mAP': None, 'Rank-1': None, 'Rank-5': None, 'Rank-10': None, 'Rank-20': None}
    
    if os.path.exists(log_file):
        with open(log_file, 'r') as f:
            content = f.read()
            # Parse metrics
            map_match = re.search(r'mAP:\s*([\d.]+)%?', content)
            r1_match = re.search(r'Rank-1\s*[:\s]+([\d.]+)%?', content)
            r5_match = re.search(r'Rank-5\s*[:\s]+([\d.]+)%?', content)
            r10_match = re.search(r'Rank-10\s*[:\s]+([\d.]+)%?', content)
            r20_match = re.search(r'Rank-20\s*[:\s]+([\d.]+)%?', content)
            
            if map_match: result['mAP'] = float(map_match.group(1))
            if r1_match: result['Rank-1'] = float(r1_match.group(1))
            if r5_match: result['Rank-5'] = float(r5_match.group(1))
            if r10_match: result['Rank-10'] = float(r10_match.group(1))
            if r20_match: result['Rank-20'] = float(r20_match.group(1))
    
    return result

# Collect all results
results = []
for exp_dir in sorted(glob(os.path.join(log_base, "sec*"))):
    exp_name = os.path.basename(exp_dir)
    metrics = parse_log(exp_dir)
    metrics['Experiment'] = exp_name
    results.append(metrics)

df = pd.DataFrame(results)
df = df[['Experiment', 'mAP', 'Rank-1', 'Rank-5', 'Rank-10', 'Rank-20']]
print("All Results Collected:")
print(df.to_string(index=False))
print(f"\nTotal experiments: {len(df)}")

# %% [markdown]
# ## 4.2 Section 1: Architecture Analysis

# %% [markdown]
# ### Table 1: Architecture Comparison

# %%
# Architecture comparison table
arch_df = df[df['Experiment'].str.contains('sec1_')].copy()
arch_df['Architecture'] = arch_df['Experiment'].str.replace('sec1_', '').str.upper()

# Model parameters (approximate)
params = {
    'MOBILENET': 2.5, 'RESNET50': 25.6, 'VGG16': 138.4,
    'RESNET18': 11.7, 'RESNET50_FC512': 24.0, 'RESNET34': 21.8
}
arch_df['Params (M)'] = arch_df['Architecture'].map(params)

print("="*70)
print("TABLE 1: Architecture Comparison")
print("="*70)
print(arch_df[['Architecture', 'Params (M)', 'mAP', 'Rank-1', 'Rank-5']].to_string(index=False))
print("="*70)

# %% [markdown]
# ### Graph 1: Parameter Count vs mAP (Scatter Plot)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

scatter = ax.scatter(arch_df['Params (M)'], arch_df['mAP'], 
                     s=150, c=range(len(arch_df)), cmap='viridis', 
                     edgecolors='black', linewidths=1.5)

for i, row in arch_df.iterrows():
    ax.annotate(row['Architecture'], (row['Params (M)'], row['mAP']),
                xytext=(5, 5), textcoords='offset points', fontsize=9)

ax.set_xlabel('Parameters (Millions)', fontsize=12)
ax.set_ylabel('mAP (%)', fontsize=12)
ax.set_title('Architecture Efficiency: Parameters vs Performance', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{log_base}plot_arch_params_vs_map.png', dpi=150)
plt.show()
print(f"Saved: {log_base}plot_arch_params_vs_map.png")

# %% [markdown]
# ### Graph 2: Architecture mAP & Rank-1 Bar Chart

# %%
fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(len(arch_df))
width = 0.35

bars1 = ax.bar(x - width/2, arch_df['mAP'], width, label='mAP', color='steelblue')
bars2 = ax.bar(x + width/2, arch_df['Rank-1'], width, label='Rank-1', color='coral')

ax.set_xlabel('Architecture', fontsize=12)
ax.set_ylabel('Performance (%)', fontsize=12)
ax.set_title('Architecture Performance Comparison', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(arch_df['Architecture'], rotation=45, ha='right')
ax.legend()
ax.grid(axis='y', alpha=0.3)

# Add value labels on bars
for bar in bars1:
    height = bar.get_height()
    if height: ax.annotate(f'{height:.1f}', xy=(bar.get_x() + bar.get_width()/2, height),
                           xytext=(0, 3), textcoords="offset points", ha='center', fontsize=8)
for bar in bars2:
    height = bar.get_height()
    if height: ax.annotate(f'{height:.1f}', xy=(bar.get_x() + bar.get_width()/2, height),
                           xytext=(0, 3), textcoords="offset points", ha='center', fontsize=8)

plt.tight_layout()
plt.savefig(f'{log_base}plot_arch_comparison.png', dpi=150)
plt.show()

# %% [markdown]
# ### Graph 3: CMC Curve (All Architectures)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ranks = ['Rank-1', 'Rank-5', 'Rank-10', 'Rank-20']
colors = plt.cm.tab10(np.linspace(0, 1, len(arch_df)))

for idx, (_, row) in enumerate(arch_df.iterrows()):
    values = [row[r] for r in ranks if row[r] is not None]
    if values:
        ax.plot([1, 5, 10, 20][:len(values)], values, 
                marker='o', linewidth=2, markersize=8,
                label=row['Architecture'], color=colors[idx])

ax.set_xlabel('Rank', fontsize=12)
ax.set_ylabel('Recognition Rate (%)', fontsize=12)
ax.set_title('CMC Curves: Architecture Comparison', fontsize=14, fontweight='bold')
ax.set_xticks([1, 5, 10, 20])
ax.legend(loc='lower right')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'{log_base}plot_arch_cmc.png', dpi=150)
plt.show()

# %% [markdown]
# ## 4.3 Section 2: Augmentation Analysis

# %% [markdown]
# ### Table 2: Augmentation Ablation

# %%
aug_df = df[df['Experiment'].str.contains('sec2_')].copy()
aug_df['Augmentation'] = aug_df['Experiment'].str.replace('sec2_', '').str.replace('_', ' ').str.title()

print("="*70)
print("TABLE 2: Augmentation Ablation Study")
print("="*70)
print(aug_df[['Augmentation', 'mAP', 'Rank-1', 'Rank-5']].to_string(index=False))
print("="*70)

# Calculate improvement over baseline
if 'baseline' in aug_df['Augmentation'].str.lower().values:
    baseline_map = aug_df[aug_df['Augmentation'].str.lower() == 'baseline']['mAP'].values[0]
    aug_df['mAP Δ'] = aug_df['mAP'] - baseline_map
    print("\nImprovement over Baseline:")
    print(aug_df[['Augmentation', 'mAP', 'mAP Δ']].to_string(index=False))

# %% [markdown]
# ### Graph 4: Augmentation Performance Bar Chart

# %%
fig, ax = plt.subplots(figsize=(12, 6))

colors = ['gray' if 'baseline' in x.lower() else 'steelblue' for x in aug_df['Augmentation']]
bars = ax.bar(aug_df['Augmentation'], aug_df['mAP'], color=colors, edgecolor='black')

ax.set_xlabel('Augmentation Strategy', fontsize=12)
ax.set_ylabel('mAP (%)', fontsize=12)
ax.set_title('Data Augmentation Impact on Performance', fontsize=14, fontweight='bold')
ax.set_xticklabels(aug_df['Augmentation'], rotation=45, ha='right')
ax.grid(axis='y', alpha=0.3)

# Highlight best
if len(aug_df) > 0 and aug_df['mAP'].notna().any():
    best_idx = aug_df['mAP'].idxmax()
    bars[list(aug_df.index).index(best_idx)].set_color('green')

for bar in bars:
    height = bar.get_height()
    if height: ax.annotate(f'{height:.1f}', xy=(bar.get_x() + bar.get_width()/2, height),
                           xytext=(0, 3), textcoords="offset points", ha='center', fontsize=9)

plt.tight_layout()
plt.savefig(f'{log_base}plot_aug_comparison.png', dpi=150)
plt.show()

# %% [markdown]
# ### Graph 5: Augmentation Heatmap

# %%
fig, ax = plt.subplots(figsize=(10, 6))

heatmap_data = aug_df[['Augmentation', 'mAP', 'Rank-1', 'Rank-5']].set_index('Augmentation')
sns.heatmap(heatmap_data, annot=True, fmt='.1f', cmap='YlGnBu', 
            linewidths=0.5, ax=ax, cbar_kws={'label': 'Performance (%)'})

ax.set_title('Augmentation Performance Heatmap', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{log_base}plot_aug_heatmap.png', dpi=150)
plt.show()

# %% [markdown]
# ## 4.4 Section 3: Hyperparameter Analysis

# %% [markdown]
# ### Table 3: Learning Rate Sweep

# %%
lr_df = df[df['Experiment'].str.contains('sec3_lr_')].copy()
lr_df['LR'] = lr_df['Experiment'].str.extract(r'lr_(.+)')[0].str.replace('_', '.')
lr_df['LR'] = lr_df['LR'].apply(lambda x: x.replace('1e05', '1e-05').replace('3e05', '3e-05'))

print("="*70)
print("TABLE 3: Learning Rate Exploration")
print("="*70)
print(lr_df[['LR', 'mAP', 'Rank-1']].to_string(index=False))
print("="*70)

# %% [markdown]
# ### Graph 6: Learning Rate Sensitivity Curve

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Convert LR to numeric for plotting
lr_df['LR_numeric'] = lr_df['LR'].astype(float)
lr_df_sorted = lr_df.sort_values('LR_numeric')

ax.plot(lr_df_sorted['LR_numeric'], lr_df_sorted['mAP'], 
        marker='o', linewidth=2, markersize=10, color='steelblue')

ax.set_xscale('log')
ax.set_xlabel('Learning Rate (log scale)', fontsize=12)
ax.set_ylabel('mAP (%)', fontsize=12)
ax.set_title('Learning Rate Sensitivity Curve', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)

# Mark best LR
if lr_df_sorted['mAP'].notna().any():
    best_idx = lr_df_sorted['mAP'].idxmax()
    best_lr = lr_df_sorted.loc[best_idx, 'LR_numeric']
    best_map = lr_df_sorted.loc[best_idx, 'mAP']
    ax.scatter([best_lr], [best_map], s=200, c='red', marker='*', zorder=5, label=f'Best: LR={best_lr}')
    ax.legend()

plt.tight_layout()
plt.savefig(f'{log_base}plot_lr_sensitivity.png', dpi=150)
plt.show()

# %% [markdown]
# ### Table 4: Batch Size Sweep

# %%
bs_df = df[df['Experiment'].str.contains('sec3_bs_')].copy()
bs_df['BatchSize'] = bs_df['Experiment'].str.extract(r'bs_(\d+)')[0].astype(int)
bs_df = bs_df.sort_values('BatchSize')

print("="*70)
print("TABLE 4: Batch Size Exploration")
print("="*70)
print(bs_df[['BatchSize', 'mAP', 'Rank-1']].to_string(index=False))
print("="*70)

# %% [markdown]
# ### Graph 7: Batch Size Impact

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(bs_df['BatchSize'].astype(str), bs_df['mAP'], color='steelblue', edgecolor='black')

ax.set_xlabel('Batch Size', fontsize=12)
ax.set_ylabel('mAP (%)', fontsize=12)
ax.set_title('Batch Size Impact on Performance', fontsize=14, fontweight='bold')
ax.grid(axis='y', alpha=0.3)

for i, (_, row) in enumerate(bs_df.iterrows()):
    if row['mAP']: ax.annotate(f"{row['mAP']:.1f}", (i, row['mAP']), 
                               ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig(f'{log_base}plot_bs_comparison.png', dpi=150)
plt.show()

# %% [markdown]
# ### Table 5: Optimizer Comparison

# %%
optim_df = df[df['Experiment'].str.contains('sec3_optim_')].copy()
optim_df['Optimizer'] = optim_df['Experiment'].str.replace('sec3_optim_', '').str.upper()

print("="*70)
print("TABLE 5: Optimizer Comparison")
print("="*70)
print(optim_df[['Optimizer', 'mAP', 'Rank-1']].to_string(index=False))
print("="*70)

# %% [markdown]
# ### Graph 8: Optimizer Performance

# %%
fig, ax = plt.subplots(figsize=(10, 6))

x = np.arange(len(optim_df))
width = 0.35

bars1 = ax.bar(x - width/2, optim_df['mAP'], width, label='mAP', color='steelblue')
bars2 = ax.bar(x + width/2, optim_df['Rank-1'], width, label='Rank-1', color='coral')

ax.set_xlabel('Optimizer', fontsize=12)
ax.set_ylabel('Performance (%)', fontsize=12)
ax.set_title('Optimizer Comparison', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(optim_df['Optimizer'])
ax.legend()
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(f'{log_base}plot_optim_comparison.png', dpi=150)
plt.show()

# %% [markdown]
# ### Table 6: Triplet Margin Tuning

# %%
margin_df = df[df['Experiment'].str.contains('sec3_margin_')].copy()
margin_df['Margin'] = margin_df['Experiment'].str.extract(r'margin_(.+)')[0].str.replace('_', '.')

print("="*70)
print("TABLE 6: Triplet Loss Margin Tuning")
print("="*70)
print(margin_df[['Margin', 'mAP', 'Rank-1']].to_string(index=False))
print("="*70)

# %% [markdown]
# ### Graph 9: Margin Impact

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(margin_df['Margin'], margin_df['mAP'], marker='s', linewidth=2, 
        markersize=12, color='purple', label='mAP')
ax.plot(margin_df['Margin'], margin_df['Rank-1'], marker='o', linewidth=2, 
        markersize=12, color='orange', label='Rank-1')

ax.set_xlabel('Triplet Loss Margin', fontsize=12)
ax.set_ylabel('Performance (%)', fontsize=12)
ax.set_title('Triplet Loss Margin Impact', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(f'{log_base}plot_margin_impact.png', dpi=150)
plt.show()

# %% [markdown]
# ## 4.5 Final Summary

# %% [markdown]
# ### Table 7: Best Configuration Summary (Section 4 Requirement)

# %%
print("="*80)
print("SECTION 4: SUMMARY TABLE - Best Configurations")
print("="*80)

summary_data = []

# Best Architecture
if len(arch_df) > 0 and arch_df['mAP'].notna().any():
    best_arch = arch_df.loc[arch_df['mAP'].idxmax()]
    summary_data.append({
        'Section': '1', 'Hyperparameter': 'Architecture',
        'Best Config': best_arch['Architecture'],
        'mAP': best_arch['mAP'], 'Rank-1': best_arch['Rank-1']
    })

# Best Augmentation
if len(aug_df) > 0 and aug_df['mAP'].notna().any():
    best_aug = aug_df.loc[aug_df['mAP'].idxmax()]
    summary_data.append({
        'Section': '2', 'Hyperparameter': 'Data Augmentation',
        'Best Config': best_aug['Augmentation'],
        'mAP': best_aug['mAP'], 'Rank-1': best_aug['Rank-1']
    })

# Best LR
if len(lr_df) > 0 and lr_df['mAP'].notna().any():
    best_lr = lr_df.loc[lr_df['mAP'].idxmax()]
    summary_data.append({
        'Section': '3.1', 'Hyperparameter': 'Learning Rate',
        'Best Config': best_lr['LR'],
        'mAP': best_lr['mAP'], 'Rank-1': best_lr['Rank-1']
    })

# Best BS
if len(bs_df) > 0 and bs_df['mAP'].notna().any():
    best_bs = bs_df.loc[bs_df['mAP'].idxmax()]
    summary_data.append({
        'Section': '3.2', 'Hyperparameter': 'Batch Size',
        'Best Config': str(best_bs['BatchSize']),
        'mAP': best_bs['mAP'], 'Rank-1': best_bs['Rank-1']
    })

# Best Optimizer
if len(optim_df) > 0 and optim_df['mAP'].notna().any():
    best_optim = optim_df.loc[optim_df['mAP'].idxmax()]
    summary_data.append({
        'Section': '3.3', 'Hyperparameter': 'Optimizer',
        'Best Config': best_optim['Optimizer'],
        'mAP': best_optim['mAP'], 'Rank-1': best_optim['Rank-1']
    })

summary_df = pd.DataFrame(summary_data)
print(summary_df.to_string(index=False))
print("="*80)

# %% [markdown]
# ### Graph 10: Overall Performance Comparison

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Architecture comparison
ax1 = axes[0, 0]
if len(arch_df) > 0:
    ax1.barh(arch_df['Architecture'], arch_df['mAP'], color='steelblue')
    ax1.set_xlabel('mAP (%)')
    ax1.set_title('Architecture Performance', fontweight='bold')

# 2. Augmentation comparison
ax2 = axes[0, 1]
if len(aug_df) > 0:
    ax2.barh(aug_df['Augmentation'], aug_df['mAP'], color='coral')
    ax2.set_xlabel('mAP (%)')
    ax2.set_title('Augmentation Performance', fontweight='bold')

# 3. LR comparison
ax3 = axes[1, 0]
if len(lr_df) > 0:
    ax3.plot(lr_df_sorted['LR_numeric'], lr_df_sorted['mAP'], marker='o', color='green')
    ax3.set_xscale('log')
    ax3.set_xlabel('Learning Rate')
    ax3.set_ylabel('mAP (%)')
    ax3.set_title('Learning Rate Sensitivity', fontweight='bold')

# 4. Optimizer comparison
ax4 = axes[1, 1]
if len(optim_df) > 0:
    ax4.bar(optim_df['Optimizer'], optim_df['mAP'], color='purple')
    ax4.set_xlabel('Optimizer')
    ax4.set_ylabel('mAP (%)')
    ax4.set_title('Optimizer Comparison', fontweight='bold')

plt.suptitle('Comprehensive Hyperparameter Analysis', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(f'{log_base}plot_summary_all.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Graph 11: Full Results Heatmap

# %%
fig, ax = plt.subplots(figsize=(12, 16))

# Prepare data for heatmap
heatmap_df = df[['Experiment', 'mAP', 'Rank-1']].dropna().set_index('Experiment')

if len(heatmap_df) > 0:
    sns.heatmap(heatmap_df, annot=True, fmt='.1f', cmap='RdYlGn', 
                linewidths=0.5, ax=ax, cbar_kws={'label': 'Performance (%)'})
    ax.set_title('All Experiments Performance Heatmap', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.savefig(f'{log_base}plot_full_heatmap.png', dpi=150)
    plt.show()
else:
    print("No data available for heatmap")

# %% [markdown]
# ### Export Results to CSV

# %% [markdown]
# ### Graph 12: Training Loss Curves

# %%
def parse_training_loss(log_dir):
    """Extract epoch-wise training loss from log file."""
    log_file = os.path.join(log_dir, "log_train.txt")
    epochs, losses = [], []
    
    if os.path.exists(log_file):
        with open(log_file, 'r') as f:
            for line in f:
                # Match patterns like "Epoch [1/60]" and "Loss: 5.1234"
                epoch_match = re.search(r'Epoch\s*\[?(\d+)', line)
                loss_match = re.search(r'Loss[:\s]+([\d.]+)', line)
                if epoch_match and loss_match:
                    epochs.append(int(epoch_match.group(1)))
                    losses.append(float(loss_match.group(1)))
    
    return epochs, losses

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Architecture loss curves
ax1 = axes[0]
arch_experiments = ['sec1_mobilenet', 'sec1_resnet50', 'sec1_resnet18', 'sec1_vgg16']
colors = plt.cm.tab10(np.linspace(0, 1, len(arch_experiments)))

for idx, exp in enumerate(arch_experiments):
    exp_dir = os.path.join(log_base, exp)
    epochs, losses = parse_training_loss(exp_dir)
    if epochs and losses:
        ax1.plot(epochs, losses, label=exp.replace('sec1_', '').upper(), 
                color=colors[idx], linewidth=2)

ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Training Loss', fontsize=12)
ax1.set_title('Training Loss: Architecture Comparison', fontsize=12, fontweight='bold')
ax1.legend(loc='upper right')
ax1.grid(True, alpha=0.3)

# Augmentation loss curves
ax2 = axes[1]
aug_experiments = ['sec2_baseline', 'sec2_jitter', 'sec2_erase', 'sec2_combo']
colors = plt.cm.Set2(np.linspace(0, 1, len(aug_experiments)))

for idx, exp in enumerate(aug_experiments):
    exp_dir = os.path.join(log_base, exp)
    epochs, losses = parse_training_loss(exp_dir)
    if epochs and losses:
        ax2.plot(epochs, losses, label=exp.replace('sec2_', '').title(), 
                color=colors[idx], linewidth=2)

ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Training Loss', fontsize=12)
ax2.set_title('Training Loss: Augmentation Comparison', fontsize=12, fontweight='bold')
ax2.legend(loc='upper right')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(f'{log_base}plot_training_curves.png', dpi=150)
plt.show()
print(f"Saved: {log_base}plot_training_curves.png")

# %% [markdown]
# ### Graph 13: Convergence Plot (Loss vs mAP over Training)

# %%
def parse_convergence_data(log_dir):
    """Extract both loss and mAP over epochs."""
    log_file = os.path.join(log_dir, "log_train.txt")
    data = {'epoch': [], 'loss': [], 'mAP': []}
    
    if os.path.exists(log_file):
        with open(log_file, 'r') as f:
            content = f.read()
            # Find evaluation blocks
            eval_blocks = re.findall(r'Epoch\s*\[?(\d+).*?Loss[:\s]+([\d.]+).*?mAP[:\s]+([\d.]+)', 
                                     content, re.DOTALL)
            for epoch, loss, mAP in eval_blocks:
                data['epoch'].append(int(epoch))
                data['loss'].append(float(loss))
                data['mAP'].append(float(mAP))
    
    return data

fig, ax1 = plt.subplots(figsize=(10, 6))

# Use best performing model for convergence analysis
best_exp = 'sec1_resnet50'
conv_data = parse_convergence_data(os.path.join(log_base, best_exp))

if conv_data['epoch']:
    color1 = 'steelblue'
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Training Loss', color=color1, fontsize=12)
    ax1.plot(conv_data['epoch'], conv_data['loss'], color=color1, linewidth=2, label='Loss')
    ax1.tick_params(axis='y', labelcolor=color1)
    
    ax2 = ax1.twinx()
    color2 = 'coral'
    ax2.set_ylabel('Validation mAP (%)', color=color2, fontsize=12)
    ax2.plot(conv_data['epoch'], conv_data['mAP'], color=color2, linewidth=2, label='mAP')
    ax2.tick_params(axis='y', labelcolor=color2)
    
    plt.title(f'Convergence Analysis: {best_exp}', fontsize=14, fontweight='bold')
    fig.legend(loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=2)
else:
    ax1.text(0.5, 0.5, 'Run experiments first to see convergence data', 
             ha='center', va='center', transform=ax1.transAxes)

plt.tight_layout()
plt.savefig(f'{log_base}plot_convergence.png', dpi=150)
plt.show()

# %% [markdown]
# ### Graph 14: Radar Chart - Multi-Metric Architecture Comparison

# %%
from math import pi

def create_radar_chart(df, title, filename):
    """Create radar chart for multi-metric comparison."""
    
    # Select metrics for radar
    metrics = ['mAP', 'Rank-1', 'Rank-5', 'Rank-10']
    available_metrics = [m for m in metrics if m in df.columns and df[m].notna().any()]
    
    if len(available_metrics) < 3 or len(df) == 0:
        print(f"Not enough data for radar chart: {title}")
        return
    
    # Number of variables
    num_vars = len(available_metrics)
    
    # Compute angle for each axis
    angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
    angles += angles[:1]  # Complete the loop
    
    # Initialize figure
    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
    
    # Colors
    colors = plt.cm.tab10(np.linspace(0, 1, len(df)))
    
    for idx, (_, row) in enumerate(df.iterrows()):
        values = [row[m] if pd.notna(row[m]) else 0 for m in available_metrics]
        values += values[:1]  # Complete the loop
        
        ax.plot(angles, values, 'o-', linewidth=2, label=row.get('Architecture', row.get('Experiment', f'Model {idx}')), color=colors[idx])
        ax.fill(angles, values, alpha=0.1, color=colors[idx])
    
    # Set labels
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(available_metrics, fontsize=11)
    ax.set_title(title, fontsize=14, fontweight='bold', y=1.08)
    ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1.0))
    
    plt.tight_layout()
    plt.savefig(f'{log_base}{filename}', dpi=150, bbox_inches='tight')
    plt.show()

# Create radar chart for architectures
if len(arch_df) > 0:
    create_radar_chart(arch_df, 'Architecture Multi-Metric Comparison', 'plot_radar_arch.png')
else:
    print("Run architecture experiments first")

# %% [markdown]
# ### Graph 15: t-SNE Feature Embedding Visualization

# %%
from sklearn.manifold import TSNE
import torch
import pickle

def load_and_visualize_embeddings(exp_name):
    """Load saved features and visualize with t-SNE."""
    feature_file = os.path.join(log_base, exp_name, 'features.pkl')
    
    # Check if features were saved during evaluation
    if not os.path.exists(feature_file):
        print(f"Feature file not found: {feature_file}")
        print("Note: Features need to be saved during model evaluation.")
        print("This visualization will work after running experiments with --visualize-ranks flag.")
        return None
    
    with open(feature_file, 'rb') as f:
        data = pickle.load(f)
    
    features = data['features']
    labels = data['labels']
    
    # Apply t-SNE
    print(f"Running t-SNE on {len(features)} samples...")
    tsne = TSNE(n_components=2, random_state=42, perplexity=30)
    embeddings_2d = tsne.fit_transform(features)
    
    return embeddings_2d, labels

# Attempt to visualize embeddings
fig, ax = plt.subplots(figsize=(10, 8))

# Try to load embeddings from best model
try:
    result = load_and_visualize_embeddings('sec1_resnet50')
    if result:
        embeddings_2d, labels = result
        unique_labels = np.unique(labels)[:20]  # Show only first 20 identities
        
        for label in unique_labels:
            mask = labels == label
            ax.scatter(embeddings_2d[mask, 0], embeddings_2d[mask, 1], 
                      label=f'ID {label}', alpha=0.6, s=30)
        
        ax.set_xlabel('t-SNE Dimension 1', fontsize=12)
        ax.set_ylabel('t-SNE Dimension 2', fontsize=12)
        ax.set_title('t-SNE Visualization of Learned Embeddings', fontsize=14, fontweight='bold')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
except Exception as e:
    ax.text(0.5, 0.5, 't-SNE Visualization\n\nFeatures need to be extracted first.\nRun experiments with feature saving enabled.', 
            ha='center', va='center', transform=ax.transAxes, fontsize=12)
    ax.set_title('t-SNE Feature Embedding (Placeholder)', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.savefig(f'{log_base}plot_tsne_embeddings.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Graph 16: Sample Re-ID Retrieval Results

# %%
def visualize_retrieval_results():
    """Visualize sample query and top-5 retrieval results."""
    
    # Check for saved visualization results
    vis_dir = os.path.join(log_base, 'sec1_resnet50', 'visrank')
    
    fig, axes = plt.subplots(2, 6, figsize=(15, 6))
    
    if os.path.exists(vis_dir):
        # Load actual retrieval results if available
        query_images = sorted(glob(os.path.join(vis_dir, 'query_*.jpg')))[:2]
        
        for row, q_img in enumerate(query_images):
            # Display query
            img = plt.imread(q_img)
            axes[row, 0].imshow(img)
            axes[row, 0].set_title('Query', fontsize=10, fontweight='bold')
            axes[row, 0].axis('off')
            axes[row, 0].add_patch(plt.Rectangle((0,0), img.shape[1], img.shape[0], 
                                                  fill=False, edgecolor='blue', linewidth=3))
            
            # Display top-5 matches
            gallery_images = sorted(glob(os.path.join(vis_dir, f'gallery_{row}_*.jpg')))[:5]
            for col, g_img in enumerate(gallery_images):
                img = plt.imread(g_img)
                axes[row, col+1].imshow(img)
                # Green border for correct match, red for incorrect
                color = 'green' if 'correct' in g_img else 'red'
                axes[row, col+1].add_patch(plt.Rectangle((0,0), img.shape[1], img.shape[0], 
                                                          fill=False, edgecolor=color, linewidth=3))
                axes[row, col+1].set_title(f'Rank-{col+1}', fontsize=9)
                axes[row, col+1].axis('off')
    else:
        # Placeholder visualization
        for row in range(2):
            for col in range(6):
                axes[row, col].set_facecolor('#f0f0f0')
                if col == 0:
                    axes[row, col].text(0.5, 0.5, f'Query {row+1}', ha='center', va='center')
                    axes[row, col].set_title('Query', fontweight='bold')
                else:
                    axes[row, col].text(0.5, 0.5, f'Match', ha='center', va='center')
                    axes[row, col].set_title(f'Rank-{col}')
                axes[row, col].axis('off')
        
        fig.text(0.5, 0.02, 'Run experiments with --visualize-ranks to see actual retrieval results', 
                ha='center', fontsize=10, style='italic')
    
    plt.suptitle('Vehicle Re-ID: Query and Top-5 Retrieved Results', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.savefig(f'{log_base}plot_retrieval_samples.png', dpi=150, bbox_inches='tight')
    plt.show()

visualize_retrieval_results()

# %% [markdown]
# ### Graph 17: Training Time & Efficiency Comparison

# %%
def parse_training_time(log_dir):
    """Extract training time from log file."""
    log_file = os.path.join(log_dir, "log_train.txt")
    
    if os.path.exists(log_file):
        with open(log_file, 'r') as f:
            content = f.read()
            # Look for total time or time per epoch
            time_match = re.search(r'Total time[:\s]+([\d.]+)\s*(s|min|h)', content, re.IGNORECASE)
            epoch_time_match = re.search(r'Time[:\s]+([\d.]+)\s*s/epoch', content, re.IGNORECASE)
            
            if time_match:
                time_val = float(time_match.group(1))
                unit = time_match.group(2).lower()
                if unit == 'min': time_val *= 60
                elif unit == 'h': time_val *= 3600
                return time_val
            elif epoch_time_match:
                return float(epoch_time_match.group(1)) * 60  # Assume 60 epochs
    return None

# Collect training times
time_data = []
for _, row in arch_df.iterrows():
    exp_dir = os.path.join(log_base, row['Experiment'])
    train_time = parse_training_time(exp_dir)
    time_data.append({
        'Architecture': row['Architecture'],
        'Params (M)': row.get('Params (M)', 0),
        'mAP': row['mAP'],
        'Training Time (s)': train_time if train_time else np.nan
    })

time_df = pd.DataFrame(time_data)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Training time comparison
ax1 = axes[0]
if time_df['Training Time (s)'].notna().any():
    bars = ax1.bar(time_df['Architecture'], time_df['Training Time (s)'] / 60, 
                   color='steelblue', edgecolor='black')
    ax1.set_ylabel('Training Time (minutes)', fontsize=12)
else:
    # Estimate based on parameters
    estimated_times = time_df['Params (M)'] * 2  # Rough estimate
    bars = ax1.bar(time_df['Architecture'], estimated_times, color='lightsteelblue', edgecolor='black')
    ax1.set_ylabel('Estimated Training Time (minutes)', fontsize=12)
    ax1.text(0.5, 0.95, '* Estimated from model parameters', transform=ax1.transAxes, 
             ha='center', fontsize=9, style='italic')

ax1.set_xlabel('Architecture', fontsize=12)
ax1.set_title('Training Time Comparison', fontsize=12, fontweight='bold')
ax1.set_xticklabels(time_df['Architecture'], rotation=45, ha='right')
ax1.grid(axis='y', alpha=0.3)

# Plot 2: Efficiency (mAP per parameter)
ax2 = axes[1]
efficiency = time_df['mAP'] / time_df['Params (M)']
colors = ['green' if e == efficiency.max() else 'steelblue' for e in efficiency]
ax2.bar(time_df['Architecture'], efficiency, color=colors, edgecolor='black')
ax2.set_xlabel('Architecture', fontsize=12)
ax2.set_ylabel('Efficiency (mAP / Parameters)', fontsize=12)
ax2.set_title('Model Efficiency: Performance per Parameter', fontsize=12, fontweight='bold')
ax2.set_xticklabels(time_df['Architecture'], rotation=45, ha='right')
ax2.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(f'{log_base}plot_training_efficiency.png', dpi=150)
plt.show()

# %% [markdown]
# ### Graph 18: 3D Surface Plot - LR × Batch Size × mAP Interaction

# %%
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata

# Get LR and BS experiment results
lr_results = []
for _, row in lr_df.iterrows():
    if pd.notna(row['mAP']):
        lr_results.append({'LR': float(row['LR']), 'BS': 64, 'mAP': row['mAP']})

bs_results = []
for _, row in bs_df.iterrows():
    if pd.notna(row['mAP']):
        bs_results.append({'LR': 0.0003, 'BS': int(row['BatchSize']), 'mAP': row['mAP']})

# Combine data
combined_data = lr_results + bs_results
combined_df = pd.DataFrame(combined_data)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

if len(combined_df) > 3:
    # Create scatter plot
    scatter = ax.scatter(np.log10(combined_df['LR']), 
                        np.log2(combined_df['BS']), 
                        combined_df['mAP'],
                        c=combined_df['mAP'], cmap='viridis', 
                        s=100, edgecolors='black', linewidths=1)
    
    ax.set_xlabel('Log10(Learning Rate)', fontsize=11)
    ax.set_ylabel('Log2(Batch Size)', fontsize=11)
    ax.set_zlabel('mAP (%)', fontsize=11)
    ax.set_title('Hyperparameter Interaction: LR × BS × mAP', fontsize=14, fontweight='bold')
    
    # Add colorbar
    cbar = plt.colorbar(scatter, ax=ax, shrink=0.5, aspect=10)
    cbar.set_label('mAP (%)', fontsize=10)
    
    # Try to create surface if enough data points
    try:
        # Create grid for interpolation
        lr_range = np.linspace(combined_df['LR'].min(), combined_df['LR'].max(), 20)
        bs_range = np.linspace(combined_df['BS'].min(), combined_df['BS'].max(), 20)
        LR_grid, BS_grid = np.meshgrid(np.log10(lr_range), np.log2(bs_range))
        
        # Interpolate
        points = np.column_stack([np.log10(combined_df['LR']), np.log2(combined_df['BS'])])
        mAP_grid = griddata(points, combined_df['mAP'].values, (LR_grid, BS_grid), method='cubic')
        
        # Plot surface with transparency
        if mAP_grid is not None and not np.all(np.isnan(mAP_grid)):
            ax.plot_surface(LR_grid, BS_grid, mAP_grid, alpha=0.3, cmap='viridis')
    except Exception as e:
        print(f"Could not create surface: {e}")
else:
    ax.text2D(0.5, 0.5, 'Need more data points for 3D visualization', 
              transform=ax.transAxes, ha='center')

plt.tight_layout()
plt.savefig(f'{log_base}plot_3d_hyperparameter.png', dpi=150)
plt.show()

# %% [markdown]
# ### Graph 19: Hyperparameter Correlation Heatmap

# %%
# Create correlation analysis between different hyperparameter choices and performance

# Prepare data for correlation
corr_data = []

# Add LR experiments
for _, row in lr_df.iterrows():
    if pd.notna(row['mAP']):
        corr_data.append({
            'LR': float(row['LR']),
            'BS': 64,
            'mAP': row['mAP'],
            'Rank-1': row.get('Rank-1', np.nan)
        })

# Add BS experiments  
for _, row in bs_df.iterrows():
    if pd.notna(row['mAP']):
        corr_data.append({
            'LR': 0.0003,
            'BS': int(row['BatchSize']),
            'mAP': row['mAP'],
            'Rank-1': row.get('Rank-1', np.nan)
        })

corr_df = pd.DataFrame(corr_data)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Correlation matrix
ax1 = axes[0]
if len(corr_df) > 2:
    # Log transform LR for better correlation
    corr_df['Log_LR'] = np.log10(corr_df['LR'])
    corr_df['Log_BS'] = np.log2(corr_df['BS'])
    
    corr_matrix = corr_df[['Log_LR', 'Log_BS', 'mAP', 'Rank-1']].corr()
    sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='RdBu_r', center=0,
                ax=ax1, square=True, linewidths=0.5,
                xticklabels=['log(LR)', 'log(BS)', 'mAP', 'Rank-1'],
                yticklabels=['log(LR)', 'log(BS)', 'mAP', 'Rank-1'])
    ax1.set_title('Hyperparameter-Performance Correlation', fontsize=12, fontweight='bold')
else:
    ax1.text(0.5, 0.5, 'Need more data for correlation analysis', ha='center', va='center')
    ax1.set_title('Correlation Matrix (Placeholder)', fontsize=12)

# Performance distribution
ax2 = axes[1]
all_maps = df['mAP'].dropna()
if len(all_maps) > 0:
    ax2.hist(all_maps, bins=15, color='steelblue', edgecolor='black', alpha=0.7)
    ax2.axvline(all_maps.mean(), color='red', linestyle='--', linewidth=2, label=f'Mean: {all_maps.mean():.1f}%')
    ax2.axvline(all_maps.max(), color='green', linestyle='--', linewidth=2, label=f'Best: {all_maps.max():.1f}%')
    ax2.set_xlabel('mAP (%)', fontsize=12)
    ax2.set_ylabel('Frequency', fontsize=12)
    ax2.set_title('mAP Distribution Across All Experiments', fontsize=12, fontweight='bold')
    ax2.legend()
else:
    ax2.text(0.5, 0.5, 'Run experiments to see distribution', ha='center', va='center')

plt.tight_layout()
plt.savefig(f'{log_base}plot_correlation_analysis.png', dpi=150)
plt.show()

# %% [markdown]
# ### Graph 20: Pareto Frontier - Efficiency vs Performance Trade-off

# %%
def find_pareto_frontier(df, x_col, y_col, maximize_x=False, maximize_y=True):
    """Find Pareto optimal points."""
    pareto_points = []
    
    for i, row in df.iterrows():
        is_dominated = False
        for j, other in df.iterrows():
            if i == j:
                continue
            
            # Check if 'other' dominates 'row'
            if maximize_x and maximize_y:
                if other[x_col] >= row[x_col] and other[y_col] >= row[y_col]:
                    if other[x_col] > row[x_col] or other[y_col] > row[y_col]:
                        is_dominated = True
                        break
            elif not maximize_x and maximize_y:
                if other[x_col] <= row[x_col] and other[y_col] >= row[y_col]:
                    if other[x_col] < row[x_col] or other[y_col] > row[y_col]:
                        is_dominated = True
                        break
        
        if not is_dominated:
            pareto_points.append(i)
    
    return pareto_points

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot 1: Parameters vs mAP Pareto
ax1 = axes[0]
if len(arch_df) > 0 and 'Params (M)' in arch_df.columns:
    # Scatter all points
    ax1.scatter(arch_df['Params (M)'], arch_df['mAP'], s=150, c='steelblue', 
                edgecolors='black', linewidths=1.5, label='All Models', zorder=2)
    
    # Find and highlight Pareto frontier (minimize params, maximize mAP)
    pareto_idx = find_pareto_frontier(arch_df.reset_index(), 'Params (M)', 'mAP', 
                                       maximize_x=False, maximize_y=True)
    pareto_df = arch_df.iloc[pareto_idx].sort_values('Params (M)')
    
    if len(pareto_df) > 0:
        ax1.plot(pareto_df['Params (M)'], pareto_df['mAP'], 'r--', linewidth=2, 
                label='Pareto Frontier', zorder=1)
        ax1.scatter(pareto_df['Params (M)'], pareto_df['mAP'], s=200, c='red', 
                   marker='*', edgecolors='black', linewidths=1, label='Pareto Optimal', zorder=3)
    
    # Annotate points
    for _, row in arch_df.iterrows():
        ax1.annotate(row['Architecture'], (row['Params (M)'], row['mAP']),
                    xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    ax1.set_xlabel('Parameters (Millions)', fontsize=12)
    ax1.set_ylabel('mAP (%)', fontsize=12)
    ax1.set_title('Pareto Frontier: Model Size vs Performance', fontsize=12, fontweight='bold')
    ax1.legend(loc='lower right')
    ax1.grid(True, alpha=0.3)

# Plot 2: Improvement over baseline
ax2 = axes[1]
if len(aug_df) > 0 and 'mAP Δ' in aug_df.columns:
    colors = ['green' if x > 0 else 'red' for x in aug_df['mAP Δ']]
    bars = ax2.barh(aug_df['Augmentation'], aug_df['mAP Δ'], color=colors, edgecolor='black')
    ax2.axvline(0, color='black', linewidth=1)
    ax2.set_xlabel('mAP Change from Baseline (%)', fontsize=12)
    ax2.set_title('Augmentation Impact: Improvement over Baseline', fontsize=12, fontweight='bold')
    ax2.grid(axis='x', alpha=0.3)
    
    # Add value labels
    for bar, val in zip(bars, aug_df['mAP Δ']):
        if pd.notna(val):
            ax2.text(val + 0.1 if val >= 0 else val - 0.5, bar.get_y() + bar.get_height()/2,
                    f'{val:+.1f}', va='center', fontsize=9)
elif len(aug_df) > 0:
    ax2.barh(aug_df['Augmentation'], aug_df['mAP'], color='steelblue', edgecolor='black')
    ax2.set_xlabel('mAP (%)', fontsize=12)
    ax2.set_title('Augmentation Performance', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.savefig(f'{log_base}plot_pareto_frontier.png', dpi=150)
plt.show()

print("\n" + "="*60)
print("ALL 20 VISUALIZATIONS GENERATED!")
print("="*60)

# %% [markdown]
# ### Summary: All Generated Visualizations

# %%
print("="*70)
print("COMPLETE LIST OF GENERATED VISUALIZATIONS")
print("="*70)

plots = [
    ("Graph 1", "plot_arch_params_vs_map.png", "Parameter Count vs mAP Scatter"),
    ("Graph 2", "plot_arch_comparison.png", "Architecture mAP & Rank-1 Bar Chart"),
    ("Graph 3", "plot_arch_cmc.png", "CMC Curves for All Architectures"),
    ("Graph 4", "plot_aug_comparison.png", "Augmentation Performance Bar Chart"),
    ("Graph 5", "plot_aug_heatmap.png", "Augmentation Performance Heatmap"),
    ("Graph 6", "plot_lr_sensitivity.png", "Learning Rate Sensitivity Curve"),
    ("Graph 7", "plot_bs_comparison.png", "Batch Size Impact Bar Chart"),
    ("Graph 8", "plot_optim_comparison.png", "Optimizer Performance Comparison"),
    ("Graph 9", "plot_margin_impact.png", "Triplet Margin Impact Line Plot"),
    ("Graph 10", "plot_summary_all.png", "4-Panel Summary Overview"),
    ("Graph 11", "plot_full_heatmap.png", "Full Experiments Heatmap"),
    ("Graph 12", "plot_training_curves.png", "Training Loss Curves"),
    ("Graph 13", "plot_convergence.png", "Convergence Plot (Loss vs mAP)"),
    ("Graph 14", "plot_radar_arch.png", "Radar Chart Multi-Metric"),
    ("Graph 15", "plot_tsne_embeddings.png", "t-SNE Feature Embeddings"),
    ("Graph 16", "plot_retrieval_samples.png", "Sample Re-ID Retrieval Results"),
    ("Graph 17", "plot_training_efficiency.png", "Training Time & Efficiency"),
    ("Graph 18", "plot_3d_hyperparameter.png", "3D Surface LR×BS×mAP"),
    ("Graph 19", "plot_correlation_analysis.png", "Correlation Heatmap & Distribution"),
    ("Graph 20", "plot_pareto_frontier.png", "Pareto Frontier Analysis"),
]

print(f"{'#':<10} {'Filename':<35} {'Description':<40}")
print("-"*85)
for name, filename, desc in plots:
    print(f"{name:<10} {filename:<35} {desc:<40}")

print("-"*85)
print(f"\nTotal: {len(plots)} visualizations")
print(f"Location: {log_base}")
print("\nTables Generated: 7 (Architecture, Augmentation, LR, BS, Optimizer, Margin, Summary)")
print("="*70)

# %%
# Save all results to CSV for report
df.to_csv(f'{log_base}all_results.csv', index=False)
print(f"Results saved to: {log_base}all_results.csv")

# Save summary table
if len(summary_data) > 0:
    summary_df.to_csv(f'{log_base}summary_table.csv', index=False)
    print(f"Summary saved to: {log_base}summary_table.csv")

print("\n" + "="*60)
print("ALL VISUALIZATIONS GENERATED SUCCESSFULLY!")
print("="*60)
print(f"\nPlots saved to: {log_base}")
print("- plot_arch_params_vs_map.png")
print("- plot_arch_comparison.png")
print("- plot_arch_cmc.png")
print("- plot_aug_comparison.png")
print("- plot_aug_heatmap.png")
print("- plot_lr_sensitivity.png")
print("- plot_bs_comparison.png")
print("- plot_optim_comparison.png")
print("- plot_margin_impact.png")
print("- plot_summary_all.png")
print("- plot_full_heatmap.png")
